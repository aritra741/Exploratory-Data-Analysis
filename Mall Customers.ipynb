# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics
from scipy import stats

# %%
data= pd.read_csv("./Mall_Customers.csv")

# %%
data.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
data.shape
# Out:
# (200, 5)

# %%
data.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
data.nunique()
# Out:
# CustomerID                200
# Gender                      2
# Age                        51
# Annual Income (k$)         64
# Spending Score (1-100)     84
# dtype: int64

# %%
data = data.drop(['CustomerID'], axis= 1)

# %%
data.head()
# Out:
#    Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0    Male   19                  15                      39
# 1    Male   21                  15                      81
# 2  Female   20                  16                       6
# 3  Female   23                  16                      77
# 4  Female   31                  17                      40

# %%
correlation = data.corr()

# %%
sns.heatmap(correlation, cmap = 'coolwarm', xticklabels= correlation.columns, yticklabels= correlation.columns, annot= True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data)

# %%
sns.relplot(x= 'Age', y= 'Annual Income (k$)', hue= 'Gender', data= data)

# %%
sns.relplot(x= 'Age', y= 'Spending Score (1-100)', hue= 'Gender', data= data)

# %%
sns.displot(data['Age'], bins= 5)

# %%
sns.displot(data['Annual Income (k$)'])

# %%
labels = ['Female', 'Male']
size = data['Gender'].value_counts()
colors = ['pink', 'lightblue']
explode = [0, 0.1]

plt.rcParams['figure.figsize'] = (9, 9)
plt.pie(size, colors = colors, explode = explode, labels = labels, shadow = True, autopct = '%.2f%%')
plt.title('Gender', fontsize = 20)
plt.axis('off')
plt.legend()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (18, 7)
sns.stripplot(data['Gender'], data['Age'], palette = 'Blues', size = 10)
plt.show()
# Out:
# F:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (18, 8)

plt.subplot(1, 2, 1)
sns.set(style = 'whitegrid')
sns.distplot(data['Annual Income (k$)'])
plt.title('Distribution of Annual Income', fontsize = 20)
plt.xlabel('Range of Annual Income')
plt.ylabel('Count')


plt.subplot(1, 2, 2)
sns.set(style = 'whitegrid')
sns.distplot(data['Age'], color = 'green')
plt.title('Distribution of Age', fontsize = 20)
plt.xlabel('Range of Age')
plt.ylabel('Count')
plt.show()
# sns.distplot(data['Age'])

# %%
sns.distplot(data['Spending Score (1-100)'])
# Out:
# <AxesSubplot:xlabel='Spending Score (1-100)', ylabel='Density'>

# %%
mean1= np.mean(data['Age'])
mean2= np.mean(data['Annual Income (k$)'])
mean3= np.mean(data['Spending Score (1-100)'])
print(mean1,mean2,mean3)
# Out:
# 38.85 60.56 50.2

# %%
median1= np.median(data['Age'])
median2= np.median(data['Annual Income (k$)'])
median3= np.median(data['Spending Score (1-100)'])
print(median1,median2,median3)
# Out:
# 36.0 61.5 50.0

# %%
mode1= statistics.mode(data['Age'])
mode2= statistics.mode(data['Annual Income (k$)'])
mode3= statistics.mode(data['Spending Score (1-100)'])
mode4= statistics.mode(data['Gender'])
print(mode1, mode2, mode3, mode4)
# Out:
# 32 54 42 Female

# %%
range1= np.ptp(data['Age'])
range2= np.ptp(data['Annual Income (k$)'])
range3= np.ptp(data['Spending Score (1-100)'])
print(range1, range2, range3)
# Out:
# 52 122 98

# %%
standard_dev1= np.std(data['Age'])
standard_dev2= np.std(data['Annual Income (k$)'])
standard_dev3= np.std(data['Spending Score (1-100)'])
print(standard_dev1, standard_dev2, standard_dev3)
# Out:
# 13.934041050606966 26.19897707926782 25.75888196331509

# %%
variance1= np.var(data['Age'])
variance2= np.var(data['Annual Income (k$)'])
variance3= np.var(data['Spending Score (1-100)'])
print(variance1, variance2, variance3)
# Out:
# 194.1575000000001 686.3864000000005 663.5199999999994
